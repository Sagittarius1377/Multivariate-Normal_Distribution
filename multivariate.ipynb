# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# graph using equation of line  (negative corelation)
weight = np.random.normal(loc=70, scale=5, size=500)
height = (-2*weight) + 5 + np.random.normal(loc=20, scale=8, size=500)
data=pd.DataFrame(data={'Weight (Kgs)': weight, 'Height (cms)': height})

# %%
data
# Out:
#      Weight (Kgs)  Height (cms)
# 0       70.584890   -105.235699
# 1       71.253673   -123.093576
# 2       70.990743    -94.969144
# 3       65.478064   -100.401128
# 4       68.241776   -120.900634
# ..            ...           ...
# 495     58.759968    -80.254405
# 496     70.189758   -125.884484
# 497     67.779402    -96.911940
# 498     68.713242   -105.680286
# 499     68.383101   -111.576354
#
# [500 rows x 2 columns]

# %%
data.mean(axis=0)
# Out:
# Weight (Kgs)     70.107493
# Height (cms)   -115.447336
# dtype: float64

# %%
plt.scatter(data['Weight (Kgs)'], data['Height (cms)'])
plt.xlabel('Weight (Kgs)')
plt.ylabel('Height (cms)')
plt.title('Scatter plot of Weight vs Height')
plt.show()

# %%
# normal graph 
weight = np.random.normal(loc=70, scale=5, size=500)
height = np.random.normal(loc=170, scale=7.5, size=500)
data=pd.DataFrame(data={'Weight': weight, 'Height': height})

# %%
plt.scatter(data['Weight'], data['Height'])
plt.xlabel('Weight')
plt.ylabel('Height')
plt.title('Scatter plot of Weight vs Height')
plt.show()
